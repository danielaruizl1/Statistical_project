# %%
# !pip install optuna

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
import optuna
import joblib

# Read data
data = pd.read_excel('TrainClass.xlsx')
real_data = pd.read_excel('TestClass.xlsx')

# Prepare training data
Y, X = data['FRACASO'], data.drop(['FRACASO', 'CODIGO_EMPRESA'], axis=1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Prepare testing data
X = real_data.drop(['CODIGO_EMPRESA'], axis=1)

# Define the objective function for cross-validated AUC
def objective(trial):
    # Define hyperparameters to be optimized
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
    max_depth = trial.suggest_int('max_depth', 1, 10)

    # Create the classifier with suggested hyperparameters
    clf = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, random_state=0)

    # Define cross-validation strategy (StratifiedKFold for classification)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    # Perform cross-validation and get mean AUC
    auc_scores = cross_val_score(clf, X_train, Y_train, cv=cv, scoring='roc_auc')
    mean_auc = auc_scores.mean()

    return mean_auc

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Get the best hyperparameters
best_params = study.best_params
print(f'Best Hyperparameters: {best_params}')

# Train the final model with the best hyperparameters
best_clf = GradientBoostingClassifier(**best_params, random_state=0)
best_clf.fit(X_train, Y_train)

# Predictions on training set
y_pred_train = best_clf.predict(X_train)

# Calculate AUC for training set
auc_train = roc_auc_score(Y_train, y_pred_train)
print(f'AUC for Training Set: {auc_train:.4f}')

# Predictions on testing set
y_pred_test = best_clf.predict(X_test)

# Calculate AUC for testing set
auc_test = roc_auc_score(Y_test, y_pred_test)
print(f'AUC for Testing Set: {auc_test:.4f}')

# Save the trained model to a file
joblib.dump(best_clf, 'gradient_boosting_model.joblib')

# Load model and generate probability CSV
loaded_model = joblib.load('gradient_boosting_model.joblib')
prob = loaded_model.predict_proba(X)[:, 1]
prob_df = pd.DataFrame(prob, columns=['Probability'])
prob_df.index = prob_df.index + 1
prob_df.index.name = 'Id'
prob_df.to_csv('intento.csv', index=True)
# Out:
# [I 2023-12-05 14:36:33,341] A new study created in memory with name: no-name-eaefdf49-40a4-4ac9-b2bc-d120c679d51b
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 14:36:37,451] Trial 0 finished with value: 0.6915086736934561 and parameters: {'n_estimators': 66, 'learning_rate': 0.5697369616057512, 'max_depth': 2}. Best is trial 0 with value: 0.6915086736934561.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 14:37:12,597] Trial 1 finished with value: 0.7073008344312692 and parameters: {'n_estimators': 116, 'learning_rate': 0.10350487416255669, 'max_depth': 10}. Best is trial 1 with value: 0.7073008344312692.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 14:37:31,552] Trial 2 finished with value: 0.8125415019762847 and parameters: {'n_estimators': 160, 'learning_rate': 0.18746383753005766, 'max_depth': 4}. Best is trial 2 with value: 0.8125415019762847.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 14:37:34,559] Trial 3 finished with value: 0.8171340579710146 and parameters: {'n_estimators': 94, 'learning_rate': 0.18644582438417645, 'max_depth': 1}. Best is trial 3 with value: 0.8171340579710146.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 14:37:48,672] Trial 4 finished with value: 0.8134407114624504 and parameters: {'n_estimators': 148, 'learning_rate': 0.10918172980449722, 'max_depth': 3}. Best is trial 3 with value: 0.8171340579710146.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 14:37:54,138] Trial 5 finished with value: 0.747054347826087 and parameters: {'n_estimators': 65, 'learning_rate': 0.7972339922414904, 'max_depth': 8}. Best is trial 3 with value: 0.8171340579710146.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 14:38:00,354] Trial 6 finished with value: 0.8054359903381643 and parameters: {'n_estimators': 97, 'learning_rate': 0.11494132343323045, 'max_depth': 2}. Best is trial 3 with value: 0.8171340579710146.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 14
 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:00:55,172] Trial 79 finished with value: 0.8211057312252965 and parameters: {'n_estimators': 200, 'learning_rate': 0.02004200400518491, 'max_depth': 1}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:01:04,249] Trial 80 finished with value: 0.8080945322793148 and parameters: {'n_estimators': 139, 'learning_rate': 0.01715407099136146, 'max_depth': 2}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:01:22,062] Trial 81 finished with value: 0.820209595959596 and parameters: {'n_estimators': 147, 'learning_rate': 0.03294914987500134, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:01:41,329] Trial 82 finished with value: 0.8242980895915679 and parameters: {'n_estimators': 161, 'learning_rate': 0.022537873528186883, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:01:56,418] Trial 83 finished with value: 0.8166172595520422 and parameters: {'n_estimators': 162, 'learning_rate': 0.02343563102289208, 'max_depth': 3}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:02:14,953] Trial 84 finished with value: 0.8222962231005709 and parameters: {'n_estimators': 152, 'learning_rate': 0.018493841416635865, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:02:31,890] Trial 85 finished with value: 0.8159199604743084 and parameters: {'n_estimators': 176, 'learning_rate': 0.021634743371468274, 'max_depth': 3}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:02:51,432] Trial 86 finished with value: 0.8194097496706192 and parameters: {'n_estimators': 133, 'learning_rate': 0.02679446270028922, 'max_depth': 5}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:03:11,290] Trial 87 finished with value: 0.8260814668423364 and parameters: {'n_estimators': 168, 'learning_rate': 0.016694112969488393, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:03:32,270] Trial 88 finished with value: 0.8156469038208168 and parameters: {'n_estimators': 166, 'learning_rate': 0.01025684050402909, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:03:56,847] Trial 89 finished with value: 0.8262374835309618 and parameters: {'n_estimators': 170, 'learning_rate': 0.015011241110619125, 'max_depth': 5}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:04:22,038] Trial 90 finished with value: 0.8173893280632412 and parameters: {'n_estimators': 170, 'learning_rate': 0.012913356128623224, 'max_depth': 5}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:04:41,506] Trial 91 finished with value: 0.8169165568730786 and parameters: {'n_estimators': 160, 'learning_rate': 0.01549738707063719, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:05:01,638] Trial 92 finished with value: 0.8274533377250769 and parameters: {'n_estimators': 165, 'learning_rate': 0.01723873476711725, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:05:21,183] Trial 93 finished with value: 0.8260635704874837 and parameters: {'n_estimators': 166, 'learning_rate': 0.01442196171437395, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:05:42,124] Trial 94 finished with value: 0.8227459376372419 and parameters: {'n_estimators': 165, 'learning_rate': 0.013770121568078764, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:06:04,235] Trial 95 finished with value: 0.8183625384277559 and parameters: {'n_estimators': 153, 'learning_rate': 0.0168264970690367, 'max_depth': 5}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:06:26,036] Trial 96 finished with value: 0.8235598375054897 and parameters: {'n_estimators': 174, 'learning_rate': 0.014689231375641182, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:06:54,369] Trial 97 finished with value: 0.7638357487922705 and parameters: {'n_estimators': 160, 'learning_rate': 0.012660334746521671, 'max_depth': 6}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:07:17,581] Trial 98 finished with value: 0.810673693456302 and parameters: {'n_estimators': 149, 'learning_rate': 0.017591174693124243, 'max_depth': 5}. Best is trial 73 with value: 0.8313695652173912.
# <ipython-input-9-dba58cfe44dd>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 1.0)
# [I 2023-12-05 15:07:39,040] Trial 99 finished with value: 0.8224350021958718 and parameters: {'n_estimators': 169, 'learning_rate': 0.019642693559016697, 'max_depth': 4}. Best is trial 73 with value: 0.8313695652173912.
# Best Hyperparameters: {'n_estimators': 178, 'learning_rate': 0.016627816667251865, 'max_depth': 4}
# AUC for Training Set: 0.8220
# AUC for Testing Set: 0.5866
