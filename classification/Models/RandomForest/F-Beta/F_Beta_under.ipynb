# %%
# !pip install optuna

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import fbeta_score
import optuna
import joblib
from imblearn.under_sampling import RandomUnderSampler

# Read data
data = pd.read_excel('TrainClass.xlsx')
real_data = pd.read_excel('TestClass.xlsx')

# Prepare training data
Y, X = data['FRACASO'], data.drop(['FRACASO', 'CODIGO_EMPRESA'], axis=1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=5)

# Prepare testing data
X = real_data.drop(['CODIGO_EMPRESA'], axis=1)

# Define the objective function for BaggingClassifier with RandomForestClassifier
def bagging_rf_objective(trial):
    # Define hyperparameters for RandomForestClassifier
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 200)
    rf_max_depth = trial.suggest_int('rf_max_depth', 1, 10)

    # Define hyperparameters for BaggingClassifier
    bagging_n_estimators = trial.suggest_int('bagging_n_estimators', 10, 100)
    bagging_max_samples = trial.suggest_float('bagging_max_samples', 0.1, 1.0)

    # Create the base classifier with suggested hyperparameters
    base_classifier = RandomForestClassifier(n_estimators=rf_n_estimators, max_depth=rf_max_depth, random_state=0)

    # Create the bagging classifier with the base classifier
    bagging_classifier = BaggingClassifier(
        base_classifier,
        n_estimators=bagging_n_estimators,
        max_samples=bagging_max_samples,
        random_state=0
    )

    # Use RandomUnderSampler to undersample the majority class
    under_sampler = RandomUnderSampler(sampling_strategy='auto', random_state=0)
    X_resampled, Y_resampled = under_sampler.fit_resample(X_train, Y_train)

    # Define cross-validation strategy (StratifiedKFold for classification)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    # Perform cross-validation and get mean F-beta score
    fbeta_scores = cross_val_score(bagging_classifier, X_resampled, Y_resampled, cv=cv, scoring='f1_weighted')
    mean_fbeta = fbeta_scores.mean()

    return mean_fbeta

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(bagging_rf_objective, n_trials=100)

# Get the best hyperparameters
best_params = study.best_params
print(f'Best Hyperparameters for BaggingClassifier + RandomForestClassifier: {best_params}')

# Create the base classifier with the best hyperparameters for RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=best_params['rf_n_estimators'], max_depth=best_params['rf_max_depth'], random_state=0)

# Create the bagging classifier with the best hyperparameters
bagging_classifier = BaggingClassifier(
    rf_classifier,
    n_estimators=best_params['bagging_n_estimators'],
    max_samples=best_params['bagging_max_samples'],
    random_state=0
)

# Train the bagging classifier on the resampled data
bagging_classifier.fit(X_train, Y_train)

# Predictions on testing set
y_pred_test = bagging_classifier.predict(X_test)

# Calculate F-beta score for testing set
fbeta_test = fbeta_score(Y_test, y_pred_test, beta=2, average='weighted')
print(f'F-beta Score for Testing Set: {fbeta_test:.4f}')

# Save the trained model to a file
joblib.dump(bagging_classifier, 'bagging_rf_model.joblib')

# Load model and generate probability CSV
loaded_model = joblib.load('bagging_rf_model.joblib')
prob = loaded_model.predict_proba(X)[:, 1]
prob_df = pd.DataFrame(prob, columns=['Probability'])
prob_df.index = prob_df.index + 1
prob_df.index.name = 'Id'
prob_df.to_csv('intento.csv', index=True)
# Out:
# [I 2023-12-06 22:42:57,732] A new study created in memory with name: no-name-0cf86c4d-a52a-48c6-97b0-90c94ffb276f
# [I 2023-12-06 22:43:41,475] Trial 0 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 63, 'rf_max_depth': 4, 'bagging_n_estimators': 84, 'bagging_max_samples': 0.7699794792202498}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-06 22:45:13,340] Trial 1 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 146, 'rf_max_depth': 8, 'bagging_n_estimators': 76, 'bagging_max_samples': 0.7698456927160355}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-06 22:45:59,427] Trial 2 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 152, 'rf_max_depth': 8, 'bagging_n_estimators': 37, 'bagging_max_samples': 0.6599684657271322}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-06 22:47:08,967] Trial 3 finished with value: 0.7504394825447457 and parameters: {'rf_n_estimators': 126, 'rf_max_depth': 9, 'bagging_n_estimators': 68, 'bagging_max_samples': 0.3809202990063364}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-06 22:47:29,942] Trial 4 finished with value: 0.7502203576574286 and parameters: {'rf_n_estimators': 79, 'rf_max_depth': 7, 'bagging_n_estimators': 33, 'bagging_max_samples': 0.8033473588273913}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-06 22:48:36,557] Trial 5 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 96, 'rf_max_depth': 5, 'bagging_n_estimators': 84, 'bagging_max_samples': 0.6413895844783472}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-06 22:49:45,469] Trial 6 finished with value: 0.7403735005964107 and parameters: {'rf_n_estimators': 85, 'rf_max_depth': 2, 'bagging_n_estimators': 100, 'bagging_max_samples': 0.37723096576693305}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-06 22:50:20,805] Trial 7 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 102, 'rf_max_depth': 10, 'bagging_n_estimators': 41, 'bagging_max_samples': 0.7273398697299986}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-06 22
. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:15:30,071] Trial 79 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 174, 'rf_max_depth': 4, 'bagging_n_estimators': 87, 'bagging_max_samples': 0.7627119243965598}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:16:13,553] Trial 80 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 148, 'rf_max_depth': 8, 'bagging_n_estimators': 36, 'bagging_max_samples': 0.660054674059032}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:16:52,269] Trial 81 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 87, 'rf_max_depth': 6, 'bagging_n_estimators': 53, 'bagging_max_samples': 0.8494242799851177}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:17:18,926] Trial 82 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 66, 'rf_max_depth': 5, 'bagging_n_estimators': 48, 'bagging_max_samples': 0.7315760642161103}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:17:40,639] Trial 83 finished with value: 0.7507464312956305 and parameters: {'rf_n_estimators': 60, 'rf_max_depth': 7, 'bagging_n_estimators': 42, 'bagging_max_samples': 0.763232592783101}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:18:26,043] Trial 84 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 84, 'rf_max_depth': 6, 'bagging_n_estimators': 66, 'bagging_max_samples': 0.7081478204064764}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:18:46,482] Trial 85 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 74, 'rf_max_depth': 6, 'bagging_n_estimators': 32, 'bagging_max_samples': 0.8099689418298236}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:20:46,130] Trial 86 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 159, 'rf_max_depth': 7, 'bagging_n_estimators': 91, 'bagging_max_samples': 0.8655424735236743}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:21:58,785] Trial 87 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 105, 'rf_max_depth': 5, 'bagging_n_estimators': 84, 'bagging_max_samples': 0.834576945895485}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:23:23,515] Trial 88 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 182, 'rf_max_depth': 5, 'bagging_n_estimators': 57, 'bagging_max_samples': 0.7852162256231339}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:24:22,785] Trial 89 finished with value: 0.7403735005964107 and parameters: {'rf_n_estimators': 93, 'rf_max_depth': 2, 'bagging_n_estimators': 77, 'bagging_max_samples': 0.693621048798158}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:24:50,778] Trial 90 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 54, 'rf_max_depth': 9, 'bagging_n_estimators': 62, 'bagging_max_samples': 0.7439214873086686}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:25:46,729] Trial 91 finished with value: 0.7502203576574286 and parameters: {'rf_n_estimators': 153, 'rf_max_depth': 10, 'bagging_n_estimators': 45, 'bagging_max_samples': 0.6142570810657629}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:26:57,133] Trial 92 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 170, 'rf_max_depth': 9, 'bagging_n_estimators': 51, 'bagging_max_samples': 0.6448757062254205}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:27:19,312] Trial 93 finished with value: 0.7502203576574286 and parameters: {'rf_n_estimators': 71, 'rf_max_depth': 9, 'bagging_n_estimators': 37, 'bagging_max_samples': 0.5835672966912505}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:28:18,773] Trial 94 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 162, 'rf_max_depth': 8, 'bagging_n_estimators': 45, 'bagging_max_samples': 0.8112395581198342}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:29:20,263] Trial 95 finished with value: 0.7502203576574286 and parameters: {'rf_n_estimators': 150, 'rf_max_depth': 10, 'bagging_n_estimators': 49, 'bagging_max_samples': 0.6723025965833844}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:30:48,806] Trial 96 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 179, 'rf_max_depth': 7, 'bagging_n_estimators': 60, 'bagging_max_samples': 0.6505614927666}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:32:37,029] Trial 97 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 138, 'rf_max_depth': 10, 'bagging_n_estimators': 95, 'bagging_max_samples': 0.7179172675690599}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:33:36,288] Trial 98 finished with value: 0.7601364522417154 and parameters: {'rf_n_estimators': 133, 'rf_max_depth': 8, 'bagging_n_estimators': 54, 'bagging_max_samples': 0.7726074086224679}. Best is trial 0 with value: 0.7601364522417154.
# [I 2023-12-07 00:34:30,886] Trial 99 finished with value: 0.7502203576574286 and parameters: {'rf_n_estimators': 156, 'rf_max_depth': 4, 'bagging_n_estimators': 43, 'bagging_max_samples': 0.6026936943606849}. Best is trial 0 with value: 0.7601364522417154.
# Best Hyperparameters for BaggingClassifier + RandomForestClassifier: {'rf_n_estimators': 63, 'rf_max_depth': 4, 'bagging_n_estimators': 84, 'bagging_max_samples': 0.7699794792202498}
# F-beta Score for Testing Set: 0.9441
