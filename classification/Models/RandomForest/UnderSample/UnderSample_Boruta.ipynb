# %%
# !pip install imbalanced-learn boruta
# !pip install optuna
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Collecting boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)
# Installing collected packages: boruta
# Successfully installed boruta-0.3
# Collecting optuna
#   Downloading optuna-3.4.0-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 5.7 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.0-py3-none-any.whl (230 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.6/230.6 kB 8.8 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.0 alembic-1.13.0 colorlog-6.8.0 optuna-3.4.0

# %%
# Import necessary libraries and functions
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from imblearn.under_sampling import RandomUnderSampler
from boruta import BorutaPy
import joblib

# Read data
data = pd.read_excel('TrainClass.xlsx')
real_data = pd.read_excel('TestClass.xlsx')

# Prepare training data
Y, X = data['FRACASO'], data.drop(['FRACASO', 'CODIGO_EMPRESA'], axis=1)

# Undersample the majority class
rus = RandomUnderSampler(random_state=0)
X_resampled, Y_resampled = rus.fit_resample(X, Y)

X_train, X_test, Y_train, Y_test = train_test_split(X_resampled, Y_resampled, test_size=0.2, random_state=0)

# Prepare testing data
X_real = real_data.drop(['CODIGO_EMPRESA'], axis=1)

# Define the objective function for RandomForestClassifier with Boruta feature selection
def random_forest_objective(trial):
    # Define hyperparameters for RandomForestClassifier
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 10, 1000)
    rf_max_depth = trial.suggest_int('rf_max_depth', 1, 100)

    # Create the Random Forest classifier with suggested hyperparameters
    rf_classifier = RandomForestClassifier(n_estimators=rf_n_estimators, max_depth=rf_max_depth, random_state=0)

    # Feature selection using Boruta
    boruta_selector = BorutaPy(rf_classifier, n_estimators='auto', verbose=0, random_state=0)
    boruta_selector.fit(X_train.values, Y_train.values)

    # Get selected features
    selected_features = X_train.columns[boruta_selector.support_]

    # Check if any features are selected
    if len(selected_features) == 0:
        print("No features selected. Skipping further processing.")
        return 0

    # Use only selected features for training and testing
    X_train_selected = X_train[selected_features]
    X_test_selected = X_test[selected_features]
    X_real_selected = X_real[selected_features]

    # Define cross-validation strategy (StratifiedKFold for classification)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    # Perform cross-validation and get mean AUC
    auc_scores = cross_val_score(rf_classifier, X_train_selected, Y_train, cv=cv, scoring='roc_auc')
    mean_auc = auc_scores.mean()

    return mean_auc

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(random_forest_objective, n_trials=100)

# Get the best hyperparameters
best_params = study.best_params
print(f'Best Hyperparameters for RandomForestClassifier: {best_params}')

# Create the Random Forest classifier with the best hyperparameters
rf_classifier = RandomForestClassifier(n_estimators=best_params['rf_n_estimators'], max_depth=best_params['rf_max_depth'], random_state=0)

# Feature selection using Boruta with the best hyperparameters
boruta_selector = BorutaPy(rf_classifier, n_estimators='auto', verbose=2, random_state=0)
boruta_selector.fit(X_train.values, Y_train.values)

# Get selected features
selected_features = X_train.columns[boruta_selector.support_]

# Check if any features are selected
if len(selected_features) == 0:
    print("No features selected. Skipping further processing.")
else:
    # Use only selected features for training and testing
    X_train_selected = X_train[selected_features]
    X_test_selected = X_test[selected_features]
    X_real_selected = X_real[selected_features]

    # Train the Random Forest classifier
    rf_classifier.fit(X_train_selected, Y_train)

    # Predictions on testing set
    y_pred_test = rf_classifier.predict(X_test_selected)

    # Calculate AUC for testing set
    auc_test = roc_auc_score(Y_test, y_pred_test)
    print(f'AUC for Testing Set: {auc_test:.4f}')

    # Save the trained model to a file
    joblib.dump(rf_classifier, 'random_forest_model.joblib')

    # Load model and generate probability CSV
    loaded_model = joblib.load('random_forest_model.joblib')
    prob = loaded_model.predict_proba(X_real_selected)[:, 1]
    prob_df = pd.DataFrame(prob, columns=['Probability'])
    prob_df.index = prob_df.index + 1
    prob_df.index.name = 'Id'
    prob_df.to_csv('intento.csv', index=True)
# Out:
# [I 2023-12-05 23:36:11,975] A new study created in memory with name: no-name-60af104b-8d36-41fa-99cb-91dd0be42011
# [I 2023-12-05 23:36:13,284] Trial 0 finished with value: 0.0 and parameters: {'rf_n_estimators': 874, 'rf_max_depth': 66}. Best is trial 0 with value: 0.0.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:37:08,889] Trial 1 finished with value: 0.7820936639118456 and parameters: {'rf_n_estimators': 975, 'rf_max_depth': 2}. Best is trial 1 with value: 0.7820936639118456.
# [I 2023-12-05 23:37:10,269] Trial 2 finished with value: 0.0 and parameters: {'rf_n_estimators': 569, 'rf_max_depth': 59}. Best is trial 1 with value: 0.7820936639118456.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:37:12,049] Trial 3 finished with value: 0.609504132231405 and parameters: {'rf_n_estimators': 428, 'rf_max_depth': 46}. Best is trial 1 with value: 0.7820936639118456.
# [I 2023-12-05 23:37:13,090] Trial 4 finished with value: 0.0 and parameters: {'rf_n_estimators': 516, 'rf_max_depth': 79}. Best is trial 1 with value: 0.7820936639118456.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:37:14,939] Trial 5 finished with value: 0.6149449035812673 and parameters: {'rf_n_estimators': 308, 'rf_max_depth': 47}. Best is trial 1 with value: 0.7820936639118456.
# [I 2023-12-05 23:37:20,511] Trial 6 finished with value: 0.6910468319559229 and parameters: {'rf_n_estimators': 281, 'rf_max_depth': 19}. Best is trial 1 with value: 0.7820936639118456.
# [I 2023-12-05 23:37:21,994] Trial 7 finished with value: 0.0 and parameters: {'rf_n_estimators': 985, 'rf_max_depth': 83}. Best is trial 1 with value: 0.7820936639118456.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:37:23,022] Trial 8 finished with value: 0.0 and parameters: {'rf_n_estimators': 803, 'rf_max_depth': 81}. Best is trial 1 with value: 0.7820936639118456.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:37:24,746] Trial 9 finished with value: 0.6390495867768595 and parameters: {'rf_n_estimators': 166, 'rf_max_depth': 49}. Best is trial 1 with value: 0.7820936639118456.
# [I 2023-12-05 23:38:20,508] Trial 10 finished with value: 0.7820936639118456 and parameters: {'rf_n_estimators': 14, 'rf_max_depth': 2}. Best is trial 1 with value: 0.7820936639118456.
# [I 2023-12-05 23:40:07,563] Trial 11 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 50, 'rf_max_depth': 1}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:41:55,981] Trial 12 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 687, 'rf_max_depth': 1}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:41:59,782] Trial 13 finished with value: 0.7048209366391185 and parameters: {'rf_n_estimators': 662, 'rf_max_depth': 23}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:42:05,029] Trial 14 finished with value: 0.7048209366391185 and parameters: {'rf_n_estimators': 708, 'rf_max_depth': 23}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:42:06,143] Trial 15 finished with value: 0.0 and parameters: {'rf_n_estimators': 35, 'rf_max_depth': 98}. Best is trial 11 with value: 0.7822314049586778.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:42:13,233] Trial 16 finished with value: 0.7229338842975206 and parameters: {'rf_n_estimators': 388, 'rf_max_depth': 13}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:42:15,697] Trial 17 finished with value: 0.6730716253443527 and parameters: {'rf_n_estimators': 667, 'rf_max_depth': 37}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:42:19,787] Trial 18 finished with value: 0.6812672176308541 and parameters: {'rf_n_estimators': 194, 'rf_max_depth': 33}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:42:27,576] Trial 19 finished with value: 0.7809917355371901 and parameters: {'rf_n_estimators': 783, 'rf_max_depth': 11}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:42:31,050] Trial 20 finished with value: 0.6537878787878787 and parameters: {'rf_n_estimators': 591, 'rf_max_depth': 30}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:43:26,308] Trial 21 finished with value: 0.7820936639118456 and parameters: {'rf_n_estimators': 992, 'rf_max_depth': 2}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:43:39,552] Trial 22 finished with value: 0.781129476584022 and parameters: {'rf_n_estimators': 828, 'rf_max_depth': 8}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:45:28,249] Trial 23 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 447, 'rf_max_depth': 1}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:45:34,576] Trial 24 finished with value: 0.7451790633608816 and parameters: {'rf_n_estimators': 155, 'rf_max_depth': 15}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:45:44,931] Trial 25 finished with value: 0.771694214876033 and parameters: {'rf_n_estimators': 427, 'rf_max_depth': 10}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:47:33,487] Trial 26 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 92, 'rf_max_depth': 1}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:47:37,070] Trial 27 finished with value: 0.6843663911845731 and parameters: {'rf_n_estimators': 296, 'rf_max_depth': 26}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:47:39,431] Trial 28 finished with value: 0.656129476584022 and parameters: {'rf_n_estimators': 546, 'rf_max_depth': 39}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:47:46,561] Trial 29 finished with value: 0.7077134986225895 and parameters: {'rf_n_estimators': 889, 'rf_max_depth': 16}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:47:47,935] Trial 30 finished with value: 0.0 and parameters: {'rf_n_estimators': 629, 'rf_max_depth': 58}. Best is trial 11 with value: 0.7822314049586778.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:49:34,786] Trial 31 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 89, 'rf_max_depth': 1}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:49:46,041] Trial 32 finished with value: 0.7400826446280993 and parameters: {'rf_n_estimators': 85, 'rf_max_depth': 9}. Best is trial 11 with value: 0.7822314049586778.
# [I 2023-12-05 23:50:03,123] Trial 33 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 727, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:50:18,446] Trial 34 finished with value: 0.7746556473829201 and parameters: {'rf_n_estimators': 737, 'rf_max_depth': 7}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:50:23,917] Trial 35 finished with value: 0.7058539944903581 and parameters: {'rf_n_estimators': 492, 'rf_max_depth': 21}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:50:38,757] Trial 36 finished with value: 0.7746556473829201 and parameters: {'rf_n_estimators': 906, 'rf_max_depth': 7}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:50:44,438] Trial 37 finished with value: 0.7077134986225895 and parameters: {'rf_n_estimators': 477, 'rf_max_depth': 16}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:50:59,352] Trial 38 finished with value: 0.7746556473829201 and parameters: {'rf_n_estimators': 743, 'rf_max_depth': 7}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:51:00,833] Trial 39 finished with value: 0.6555096418732782 and parameters: {'rf_n_estimators': 367, 'rf_max_depth': 72}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:51:05,286] Trial 40 finished with value: 0.7044077134986227 and parameters: {'rf_n_estimators': 228, 'rf_max_depth': 29}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:52:52,257] Trial 41 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 125, 'rf_max_depth': 1}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:53:18,946] Trial 42 finished with value: 0.7730027548209366 and parameters: {'rf_n_estimators': 226, 'rf_max_depth': 4}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:53:24,748] Trial 43 finished with value: 0.6744490358126721 and parameters: {'rf_n_estimators': 583, 'rf_max_depth': 18}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:53:32,830] Trial 44 finished with value: 0.7328512396694216 and parameters: {'rf_n_estimators': 64, 'rf_max_depth': 12}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:55:21,255] Trial 45 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 941, 'rf_max_depth': 1}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:55:42,366] Trial 46 finished with value: 0.772038567493113 and parameters: {'rf_n_estimators': 821, 'rf_max_depth': 5}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:55:51,575] Trial 47 finished with value: 0.7328512396694216 and parameters: {'rf_n_estimators': 341, 'rf_max_depth': 12}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:55:52,513] Trial 48 finished with value: 0.0 and parameters: {'rf_n_estimators': 680, 'rf_max_depth': 99}. Best is trial 33 with value: 0.790633608815427.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:55:56,727] Trial 49 finished with value: 0.7058539944903581 and parameters: {'rf_n_estimators': 625, 'rf_max_depth': 21}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:55:57,683] Trial 50 finished with value: 0.0 and parameters: {'rf_n_estimators': 11, 'rf_max_depth': 92}. Best is trial 33 with value: 0.790633608815427.
# No features selected. Skipping further processing.
# [I 2023-12-05 23:57:46,554] Trial 51 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 89, 'rf_max_depth': 1}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:58:01,478] Trial 52 finished with value: 0.7746556473829201 and parameters: {'rf_n_estimators': 102, 'rf_max_depth': 7}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:58:28,242] Trial 53 finished with value: 0.7730027548209366 and parameters: {'rf_n_estimators': 50, 'rf_max_depth': 4}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:58:36,197] Trial 54 finished with value: 0.7229338842975206 and parameters: {'rf_n_estimators': 139, 'rf_max_depth': 13}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:58:57,992] Trial 55 finished with value: 0.772038567493113 and parameters: {'rf_n_estimators': 263, 'rf_max_depth': 5}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-05 23:58:59,908] Trial 56 finished with value: 0.6074380165289256 and parameters: {'rf_n_estimators': 190, 'rf_max_depth': 43}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:00:48,804] Trial 57 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 748, 'rf_max_depth': 1}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:00:50,564] Trial 58 finished with value: 0.590564738292011 and parameters: {'rf_n_estimators': 448, 'rf_max_depth': 52}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:01:00,004] Trial 59 finished with value: 0.7809917355371901 and parameters: {'rf_n_estimators': 525, 'rf_max_depth': 11}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:01:04,702] Trial 60 finished with value: 0.6744490358126721 and parameters: {'rf_n_estimators': 782, 'rf_max_depth': 18}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:01:31,334] Trial 61 finished with value: 0.7730027548209366 and parameters: {'rf_n_estimators': 131, 'rf_max_depth': 4}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:03:18,879] Trial 62 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 124, 'rf_max_depth': 1}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:03:29,562] Trial 63 finished with value: 0.7400826446280993 and parameters: {'rf_n_estimators': 179, 'rf_max_depth': 9}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:03:56,324] Trial 64 finished with value: 0.7730027548209366 and parameters: {'rf_n_estimators': 35, 'rf_max_depth': 4}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:04:04,215] Trial 65 finished with value: 0.737603305785124 and parameters: {'rf_n_estimators': 91, 'rf_max_depth': 14}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:04:13,842] Trial 66 finished with value: 0.7400826446280993 and parameters: {'rf_n_estimators': 65, 'rf_max_depth': 9}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:04:36,562] Trial 67 finished with value: 0.772038567493113 and parameters: {'rf_n_estimators': 853, 'rf_max_depth': 5}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:04:40,013] Trial 68 finished with value: 0.6926997245179064 and parameters: {'rf_n_estimators': 226, 'rf_max_depth': 25}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:06:28,842] Trial 69 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 618, 'rf_max_depth': 1}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:06:34,915] Trial 70 finished with value: 0.7451790633608816 and parameters: {'rf_n_estimators': 713, 'rf_max_depth': 15}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:08:23,487] Trial 71 finished with value: 0.7822314049586778 and parameters: {'rf_n_estimators': 934, 'rf_max_depth': 1}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:08:38,419] Trial 72 finished with value: 0.7746556473829201 and parameters: {'rf_n_estimators': 940, 'rf_max_depth': 7}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:09:05,160] Trial 73 finished with value: 0.7730027548209366 and parameters: {'rf_n_estimators': 158, 'rf_max_depth': 4}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:09:15,637] Trial 74 finished with value: 0.771694214876033 and parameters: {'rf_n_estimators': 962, 'rf_max_depth': 10}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:09:16,878] Trial 75 finished with value: 0.0 and parameters: {'rf_n_estimators': 557, 'rf_max_depth': 68}. Best is trial 33 with value: 0.790633608815427.
# No features selected. Skipping further processing.
# [I 2023-12-06 00:09:50,722] Trial 76 finished with value: 0.7731404958677686 and parameters: {'rf_n_estimators': 117, 'rf_max_depth': 3}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:10:05,598] Trial 77 finished with value: 0.7746556473829201 and parameters: {'rf_n_estimators': 869, 'rf_max_depth': 7}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:10:16,179] Trial 78 finished with value: 0.771694214876033 and parameters: {'rf_n_estimators': 391, 'rf_max_depth': 10}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:10:33,285] Trial 79 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 39, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:10:38,997] Trial 80 finished with value: 0.6744490358126721 and parameters: {'rf_n_estimators': 46, 'rf_max_depth': 18}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:10:56,760] Trial 81 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 30, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:11:13,929] Trial 82 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 25, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:11:31,018] Trial 83 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 11, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:11:48,688] Trial 84 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 14, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:11:57,293] Trial 85 finished with value: 0.7328512396694216 and parameters: {'rf_n_estimators': 15, 'rf_max_depth': 12}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:12:14,284] Trial 86 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 65, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:12:21,970] Trial 87 finished with value: 0.7451790633608816 and parameters: {'rf_n_estimators': 68, 'rf_max_depth': 15}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:12:38,904] Trial 88 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 32, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:12:42,943] Trial 89 finished with value: 0.6945592286501376 and parameters: {'rf_n_estimators': 28, 'rf_max_depth': 22}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:12:54,215] Trial 90 finished with value: 0.7400826446280993 and parameters: {'rf_n_estimators': 60, 'rf_max_depth': 9}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:13:11,314] Trial 91 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 13, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:13:26,323] Trial 92 finished with value: 0.7746556473829201 and parameters: {'rf_n_estimators': 29, 'rf_max_depth': 7}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:13:35,564] Trial 93 finished with value: 0.7328512396694216 and parameters: {'rf_n_estimators': 12, 'rf_max_depth': 12}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:13:52,652] Trial 94 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 73, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:14:10,167] Trial 95 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 73, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:14:16,423] Trial 96 finished with value: 0.7603994490358126 and parameters: {'rf_n_estimators': 104, 'rf_max_depth': 17}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:14:22,738] Trial 97 finished with value: 0.737603305785124 and parameters: {'rf_n_estimators': 42, 'rf_max_depth': 14}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:14:34,015] Trial 98 finished with value: 0.7400826446280993 and parameters: {'rf_n_estimators': 46, 'rf_max_depth': 9}. Best is trial 33 with value: 0.790633608815427.
# [I 2023-12-06 00:14:51,039] Trial 99 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 10, 'rf_max_depth': 6}. Best is trial 33 with value: 0.790633608815427.
# Best Hyperparameters for RandomForestClassifier: {'rf_n_estimators': 727, 'rf_max_depth': 6}
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	40
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	40
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	40
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	40
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	40
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	40
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	40
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	20
# Rejected: 	20
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	20
# Rejected: 	20
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	20
# Rejected: 	20
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	20
# Rejected: 	20
# Iteration: 	12 / 100
# Confirmed: 	4
# Tentative: 	16
# Rejected: 	20
# Iteration: 	13 / 100
# Confirmed: 	4
# Tentative: 	15
# Rejected: 	21
# Iteration: 	14 / 100
# Confirmed: 	4
# Tentative: 	15
# Rejected: 	21
# Iteration: 	15 / 100
# Confirmed: 	4
# Tentative: 	15
# Rejected: 	21
# Iteration: 	16 / 100
# Confirmed: 	4
# Tentative: 	14
# Rejected: 	22
# Iteration: 	17 / 100
# Confirmed: 	4
# Tentative: 	14
# Rejected: 	22
# Iteration: 	18 / 100
# Confirmed: 	4
# Tentative: 	14
# Rejected: 	22
# Iteration: 	19 / 100
# Confirmed: 	5
# Tentative: 	12
# Rejected: 	23
# Iteration: 	20 / 100
# Confirmed: 	5
# Tentative: 	12
# Rejected: 	23
# Iteration: 	21 / 100
# Confirmed: 	5
# Tentative: 	12
# Rejected: 	23
# Iteration: 	22 / 100
# Confirmed: 	5
# Tentative: 	12
# Rejected: 	23
# Iteration: 	23 / 100
# Confirmed: 	5
# Tentative: 	12
# Rejected: 	23
# Iteration: 	24 / 100
# Confirmed: 	5
# Tentative: 	12
# Rejected: 	23
# Iteration: 	25 / 100
# Confirmed: 	5
# Tentative: 	12
# Rejected: 	23
# Iteration: 	26 / 100
# Confirmed: 	5
# Tentative: 	11
# Rejected: 	24
# Iteration: 	27 / 100
# Confirmed: 	5
# Tentative: 	11
# Rejected: 	24
# Iteration: 	28 / 100
# Confirmed: 	5
# Tentative: 	11
# Rejected: 	24
# Iteration: 	29 / 100
# Confirmed: 	5
# Tentative: 	11
# Rejected: 	24
# Iteration: 	30 / 100
# Confirmed: 	5
# Tentative: 	11
# Rejected: 	24
# Iteration: 	31 / 100
# Confirmed: 	5
# Tentative: 	11
# Rejected: 	24
# Iteration: 	32 / 100
# Confirmed: 	5
# Tentative: 	11
# Rejected: 	24
# Iteration: 	33 / 100
# Confirmed: 	5
# Tentative: 	11
# Rejected: 	24
# Iteration: 	34 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	35 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	36 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	37 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	38 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	39 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	40 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	41 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	42 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	24
# Iteration: 	43 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	44 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	45 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	46 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	47 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	48 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	49 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	50 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	51 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	52 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	53 / 100
# Confirmed: 	8
# Tentative: 	8
# Rejected: 	24
# Iteration: 	54 / 100
# Confirmed: 	8
# Tentative: 	7
# Rejected: 	25
# Iteration: 	55 / 100
# Confirmed: 	8
# Tentative: 	7
# Rejected: 	25
# Iteration: 	56 / 100
# Confirmed: 	8
# Tentative: 	7
# Rejected: 	25
# Iteration: 	57 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	58 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	59 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	60 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	61 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	62 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	63 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	64 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	65 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	66 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	67 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	68 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	69 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	26
# Iteration: 	70 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	71 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	72 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	73 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	74 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	75 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	76 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	77 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	78 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	79 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	80 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	81 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	82 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	83 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	84 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	85 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	86 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	87 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	88 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	89 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	90 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	91 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	92 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	93 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	94 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	95 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	96 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	97 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	98 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
# Iteration: 	99 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	27
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	8
# Tentative: 	2
# Rejected: 	27
# AUC for Testing Set: 0.7143
