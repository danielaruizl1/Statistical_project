# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.4.0-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 6.8 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.0-py3-none-any.whl (230 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.6/230.6 kB 8.7 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.0 alembic-1.13.0 colorlog-6.8.0 optuna-3.4.0

# %%
# Import necessary libraries and functions
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from imblearn.under_sampling import RandomUnderSampler
import joblib

# Read data
data = pd.read_excel('TrainClass.xlsx')
real_data = pd.read_excel('TestClass.xlsx')

# Prepare training data
Y, X = data['FRACASO'], data.drop(['FRACASO', 'CODIGO_EMPRESA'], axis=1)

# Undersample the majority class
rus = RandomUnderSampler(random_state=0)
X_resampled, Y_resampled = rus.fit_resample(X, Y)

X_train, X_test, Y_train, Y_test = train_test_split(X_resampled, Y_resampled, test_size=0.2, random_state=0)

# Prepare testing data
X_real = real_data.drop(['CODIGO_EMPRESA'], axis=1)

# Define the objective function for RandomForestClassifier without Boruta feature selection
def random_forest_objective(trial):
    # Define hyperparameters for RandomForestClassifier
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 10, 1000)
    rf_max_depth = trial.suggest_int('rf_max_depth', 1, 100)

    # Create the Random Forest classifier with suggested hyperparameters
    rf_classifier = RandomForestClassifier(n_estimators=rf_n_estimators, max_depth=rf_max_depth, random_state=0)

    # Define cross-validation strategy (StratifiedKFold for classification)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    # Perform cross-validation and get mean AUC
    auc_scores = cross_val_score(rf_classifier, X_train, Y_train, cv=cv, scoring='roc_auc')
    mean_auc = auc_scores.mean()

    return mean_auc

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(random_forest_objective, n_trials=100)

# Get the best hyperparameters
best_params = study.best_params
print(f'Best Hyperparameters for RandomForestClassifier: {best_params}')

# Create the Random Forest classifier with the best hyperparameters
rf_classifier = RandomForestClassifier(n_estimators=best_params['rf_n_estimators'], max_depth=best_params['rf_max_depth'], random_state=0)

# Train the Random Forest classifier
rf_classifier.fit(X_train, Y_train)

# Predictions on testing set
y_pred_test = rf_classifier.predict(X_test)

# Calculate AUC for testing set
auc_test = roc_auc_score(Y_test, y_pred_test)
print(f'AUC for Testing Set: {auc_test:.4f}')

# Save the trained model to a file
joblib.dump(rf_classifier, 'random_forest_model.joblib')

# Load model and generate probability CSV
loaded_model = joblib.load('random_forest_model.joblib')
prob = loaded_model.predict_proba(X_real)[:, 1]
prob_df = pd.DataFrame(prob, columns=['Probability'])
prob_df.index = prob_df.index + 1
prob_df.index.name = 'Id'
prob_df.to_csv('intento.csv', index=True)
# Out:
# [I 2023-12-05 23:37:24,758] A new study created in memory with name: no-name-916c7920-4f00-4528-aae1-5e3ba5f198f0
# [I 2023-12-05 23:37:31,614] Trial 0 finished with value: 0.7933884297520661 and parameters: {'rf_n_estimators': 497, 'rf_max_depth': 35}. Best is trial 0 with value: 0.7933884297520661.
# [I 2023-12-05 23:37:38,738] Trial 1 finished with value: 0.784159779614325 and parameters: {'rf_n_estimators': 984, 'rf_max_depth': 88}. Best is trial 0 with value: 0.7933884297520661.
# [I 2023-12-05 23:37:43,207] Trial 2 finished with value: 0.7899449035812672 and parameters: {'rf_n_estimators': 689, 'rf_max_depth': 76}. Best is trial 0 with value: 0.7933884297520661.
# [I 2023-12-05 23:37:47,815] Trial 3 finished with value: 0.784297520661157 and parameters: {'rf_n_estimators': 861, 'rf_max_depth': 16}. Best is trial 0 with value: 0.7933884297520661.
# [I 2023-12-05 23:37:52,355] Trial 4 finished with value: 0.7851239669421488 and parameters: {'rf_n_estimators': 834, 'rf_max_depth': 53}. Best is trial 0 with value: 0.7933884297520661.
# [I 2023-12-05 23:37:53,547] Trial 5 finished with value: 0.7700413223140495 and parameters: {'rf_n_estimators': 153, 'rf_max_depth': 73}. Best is trial 0 with value: 0.7933884297520661.
# [I 2023-12-05 23:37:58,819] Trial 6 finished with value: 0.7849862258953167 and parameters: {'rf_n_estimators': 932, 'rf_max_depth': 50}. Best is trial 0 with value: 0.7933884297520661.
# [I 2023-12-05 23:38:01,596] Trial 7 finished with value: 0.7975206611570247 and parameters: {'rf_n_estimators': 523, 'rf_max_depth': 25}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:06,986] Trial 8 finished with value: 0.7849862258953169 and parameters: {'rf_n_estimators': 857, 'rf_max_depth': 91}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:08,516] Trial 9 finished with value: 0.7787878787878787 and parameters: {'rf_n_estimators': 283, 'rf_max_depth': 23}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:11,023] Trial 10 finished with value: 0.7958677685950413 and parameters: {'rf_n_estimators': 468, 'rf_max_depth': 10}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:13,379] Trial 11 finished with value: 0.7575757575757576 and parameters: {'rf_n_estimators': 465, 'rf_max_depth': 2}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:16,567] Trial 12 finished with value: 0.7606060606060606 and parameters: {'rf_n_estimators': 648, 'rf_max_depth': 1}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:19,032] Trial 13 finished with value: 0.7913223140495868 and parameters: {'rf_n_estimators': 334, 'rf_max_depth': 22}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:22,676] Trial 14 finished with value: 0.7881542699724517 and parameters: {'rf_n_estimators': 655, 'rf_max_depth': 40}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:22,971] Trial 15 finished with value: 0.7581955922865014 and parameters: {'rf_n_estimators': 48, 'rf_max_depth': 13}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:25,027] Trial 16 finished with value: 0.7928374655647382 and parameters: {'rf_n_estimators': 375, 'rf_max_depth': 31}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:28,041] Trial 17 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 561, 'rf_max_depth': 50}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:29,177] Trial 18 finished with value: 0.7756198347107438 and parameters: {'rf_n_estimators': 208, 'rf_max_depth': 11}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:32,063] Trial 19 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 394, 'rf_max_depth': 29}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:36,114] Trial 20 finished with value: 0.7865013774104683 and parameters: {'rf_n_estimators': 745, 'rf_max_depth': 40}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:39,194] Trial 21 finished with value: 0.7969696969696971 and parameters: {'rf_n_estimators': 571, 'rf_max_depth': 56}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:43,108] Trial 22 finished with value: 0.7929063360881543 and parameters: {'rf_n_estimators': 564, 'rf_max_depth': 63}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:45,907] Trial 23 finished with value: 0.7927685950413222 and parameters: {'rf_n_estimators': 448, 'rf_max_depth': 60}. Best is trial 7 with value: 0.7975206611570247.
# [I 2023-12-05 23:38:48,978] Trial 24 finished with value: 0.7977961432506888 and parameters: {'rf_n_estimators': 573, 'rf_max_depth': 10}. Best is trial 24 with value: 0.7977961432506888.
# [I 2023-12-05 23:38:52,177] Trial 25 finished with value: 0.7937327823691461 and parameters: {'rf_n_estimators': 597, 'rf_max_depth': 42}. Best is trial 24 with value: 0.7977961432506888.
# [I 2023-12-05 23:38:56,779] Trial 26 finished with value: 0.7881542699724517 and parameters: {'rf_n_estimators': 728, 'rf_max_depth': 24}. Best is trial 24 with value: 0.7977961432506888.
# [I 2023-12-05 23:38:59,820] Trial 27 finished with value: 0.7929063360881543 and parameters: {'rf_n_estimators': 558, 'rf_max_depth': 67}. Best is trial 24 with value: 0.7977961432506888.
# [I 2023-12-05 23:39:03,946] Trial 28 finished with value: 0.7849862258953169 and parameters: {'rf_n_estimators': 774, 'rf_max_depth': 82}. Best is trial 24 with value: 0.7977961432506888.
# [I 2023-12-05 23:39:06,737] Trial 29 finished with value: 0.7984159779614325 and parameters: {'rf_n_estimators': 514, 'rf_max_depth': 32}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:09,119] Trial 30 finished with value: 0.7858126721763086 and parameters: {'rf_n_estimators': 314, 'rf_max_depth': 33}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:11,950] Trial 31 finished with value: 0.7983471074380166 and parameters: {'rf_n_estimators': 511, 'rf_max_depth': 18}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:14,638] Trial 32 finished with value: 0.7957300275482094 and parameters: {'rf_n_estimators': 502, 'rf_max_depth': 18}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:16,911] Trial 33 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 418, 'rf_max_depth': 7}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:20,641] Trial 34 finished with value: 0.7905647382920111 and parameters: {'rf_n_estimators': 628, 'rf_max_depth': 26}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:23,864] Trial 35 finished with value: 0.7942837465564738 and parameters: {'rf_n_estimators': 517, 'rf_max_depth': 100}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:27,602] Trial 36 finished with value: 0.7898071625344352 and parameters: {'rf_n_estimators': 696, 'rf_max_depth': 20}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:30,242] Trial 37 finished with value: 0.7909090909090908 and parameters: {'rf_n_estimators': 486, 'rf_max_depth': 35}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:33,611] Trial 38 finished with value: 0.7967630853994491 and parameters: {'rf_n_estimators': 528, 'rf_max_depth': 15}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:38,143] Trial 39 finished with value: 0.7849862258953169 and parameters: {'rf_n_estimators': 787, 'rf_max_depth': 44}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:39,512] Trial 40 finished with value: 0.7670798898071625 and parameters: {'rf_n_estimators': 251, 'rf_max_depth': 6}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:42,811] Trial 41 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 604, 'rf_max_depth': 53}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:47,265] Trial 42 finished with value: 0.7899449035812672 and parameters: {'rf_n_estimators': 690, 'rf_max_depth': 18}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:49,660] Trial 43 finished with value: 0.7926997245179063 and parameters: {'rf_n_estimators': 439, 'rf_max_depth': 57}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:51,640] Trial 44 finished with value: 0.7913223140495869 and parameters: {'rf_n_estimators': 360, 'rf_max_depth': 27}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:39:54,861] Trial 45 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 595, 'rf_max_depth': 35}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:00,607] Trial 46 finished with value: 0.7754820936639119 and parameters: {'rf_n_estimators': 942, 'rf_max_depth': 4}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:04,181] Trial 47 finished with value: 0.7881542699724517 and parameters: {'rf_n_estimators': 656, 'rf_max_depth': 10}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:07,109] Trial 48 finished with value: 0.7984159779614325 and parameters: {'rf_n_estimators': 538, 'rf_max_depth': 47}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:10,262] Trial 49 finished with value: 0.7975206611570247 and parameters: {'rf_n_estimators': 523, 'rf_max_depth': 48}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:13,112] Trial 50 finished with value: 0.796694214876033 and parameters: {'rf_n_estimators': 428, 'rf_max_depth': 38}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:15,810] Trial 51 finished with value: 0.7949724517906336 and parameters: {'rf_n_estimators': 494, 'rf_max_depth': 47}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:18,690] Trial 52 finished with value: 0.7960055096418731 and parameters: {'rf_n_estimators': 530, 'rf_max_depth': 30}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:21,278] Trial 53 finished with value: 0.7958677685950413 and parameters: {'rf_n_estimators': 472, 'rf_max_depth': 49}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:25,465] Trial 54 finished with value: 0.7906336088154269 and parameters: {'rf_n_estimators': 635, 'rf_max_depth': 46}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:28,396] Trial 55 finished with value: 0.796831955922865 and parameters: {'rf_n_estimators': 539, 'rf_max_depth': 13}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:30,586] Trial 56 finished with value: 0.7952479338842975 and parameters: {'rf_n_estimators': 403, 'rf_max_depth': 23}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:33,843] Trial 57 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 602, 'rf_max_depth': 38}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:36,408] Trial 58 finished with value: 0.7905647382920111 and parameters: {'rf_n_estimators': 356, 'rf_max_depth': 16}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:39,144] Trial 59 finished with value: 0.7958677685950413 and parameters: {'rf_n_estimators': 472, 'rf_max_depth': 72}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:42,215] Trial 60 finished with value: 0.796900826446281 and parameters: {'rf_n_estimators': 570, 'rf_max_depth': 30}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:45,186] Trial 61 finished with value: 0.7945592286501377 and parameters: {'rf_n_estimators': 554, 'rf_max_depth': 57}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:48,451] Trial 62 finished with value: 0.7984159779614325 and parameters: {'rf_n_estimators': 514, 'rf_max_depth': 54}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:51,182] Trial 63 finished with value: 0.7927685950413222 and parameters: {'rf_n_estimators': 448, 'rf_max_depth': 63}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:53,923] Trial 64 finished with value: 0.797382920110193 and parameters: {'rf_n_estimators': 505, 'rf_max_depth': 52}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:56,072] Trial 65 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 391, 'rf_max_depth': 21}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:40:59,729] Trial 66 finished with value: 0.7856749311294766 and parameters: {'rf_n_estimators': 651, 'rf_max_depth': 42}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:41:00,536] Trial 67 finished with value: 0.7691460055096419 and parameters: {'rf_n_estimators': 101, 'rf_max_depth': 27}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:41:04,106] Trial 68 finished with value: 0.7953168044077135 and parameters: {'rf_n_estimators': 580, 'rf_max_depth': 62}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:41:06,900] Trial 69 finished with value: 0.796763085399449 and parameters: {'rf_n_estimators': 516, 'rf_max_depth': 48}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:41:09,223] Trial 70 finished with value: 0.759090909090909 and parameters: {'rf_n_estimators': 467, 'rf_max_depth': 1}. Best is trial 29 with value: 0.7984159779614325.
# [I 2023-12-05 23:41:12,014] Trial 71 finished with value: 0.8007575757575758 and parameters: {'rf_n_estimators': 509, 'rf_max_depth': 53}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:15,639] Trial 72 finished with value: 0.7984159779614325 and parameters: {'rf_n_estimators': 537, 'rf_max_depth': 66}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:19,042] Trial 73 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 619, 'rf_max_depth': 71}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:22,078] Trial 74 finished with value: 0.7991735537190083 and parameters: {'rf_n_estimators': 536, 'rf_max_depth': 77}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:25,238] Trial 75 finished with value: 0.796831955922865 and parameters: {'rf_n_estimators': 539, 'rf_max_depth': 82}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:29,327] Trial 76 finished with value: 0.7898071625344353 and parameters: {'rf_n_estimators': 667, 'rf_max_depth': 68}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:32,488] Trial 77 finished with value: 0.7960743801652892 and parameters: {'rf_n_estimators': 582, 'rf_max_depth': 79}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:35,124] Trial 78 finished with value: 0.7900826446280991 and parameters: {'rf_n_estimators': 487, 'rf_max_depth': 90}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:37,800] Trial 79 finished with value: 0.7926997245179063 and parameters: {'rf_n_estimators': 440, 'rf_max_depth': 67}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:42,231] Trial 80 finished with value: 0.7889807162534435 and parameters: {'rf_n_estimators': 724, 'rf_max_depth': 76}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:45,256] Trial 81 finished with value: 0.7945592286501377 and parameters: {'rf_n_estimators': 556, 'rf_max_depth': 56}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:47,967] Trial 82 finished with value: 0.7957988980716253 and parameters: {'rf_n_estimators': 503, 'rf_max_depth': 85}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:52,046] Trial 83 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 619, 'rf_max_depth': 60}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:54,993] Trial 84 finished with value: 0.7953168044077135 and parameters: {'rf_n_estimators': 544, 'rf_max_depth': 54}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:57,552] Trial 85 finished with value: 0.7925619834710743 and parameters: {'rf_n_estimators': 473, 'rf_max_depth': 8}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:41:59,857] Trial 86 finished with value: 0.7943526170798897 and parameters: {'rf_n_estimators': 424, 'rf_max_depth': 33}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:03,005] Trial 87 finished with value: 0.7974517906336087 and parameters: {'rf_n_estimators': 522, 'rf_max_depth': 75}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:06,597] Trial 88 finished with value: 0.793732782369146 and parameters: {'rf_n_estimators': 585, 'rf_max_depth': 19}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:09,106] Trial 89 finished with value: 0.793526170798898 and parameters: {'rf_n_estimators': 454, 'rf_max_depth': 13}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:11,391] Trial 90 finished with value: 0.7952479338842975 and parameters: {'rf_n_estimators': 413, 'rf_max_depth': 94}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:14,144] Trial 91 finished with value: 0.7940771349862259 and parameters: {'rf_n_estimators': 504, 'rf_max_depth': 60}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:17,773] Trial 92 finished with value: 0.7960055096418733 and parameters: {'rf_n_estimators': 531, 'rf_max_depth': 45}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:20,815] Trial 93 finished with value: 0.7953168044077135 and parameters: {'rf_n_estimators': 555, 'rf_max_depth': 52}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:24,167] Trial 94 finished with value: 0.7936639118457299 and parameters: {'rf_n_estimators': 613, 'rf_max_depth': 24}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:26,851] Trial 95 finished with value: 0.7900826446280991 and parameters: {'rf_n_estimators': 487, 'rf_max_depth': 43}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:30,719] Trial 96 finished with value: 0.7977272727272726 and parameters: {'rf_n_estimators': 579, 'rf_max_depth': 65}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:34,371] Trial 97 finished with value: 0.790633608815427 and parameters: {'rf_n_estimators': 670, 'rf_max_depth': 71}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:37,557] Trial 98 finished with value: 0.7944903581267218 and parameters: {'rf_n_estimators': 584, 'rf_max_depth': 65}. Best is trial 71 with value: 0.8007575757575758.
# [I 2023-12-05 23:42:41,190] Trial 99 finished with value: 0.796900826446281 and parameters: {'rf_n_estimators': 570, 'rf_max_depth': 55}. Best is trial 71 with value: 0.8007575757575758.
# Best Hyperparameters for RandomForestClassifier: {'rf_n_estimators': 509, 'rf_max_depth': 53}
# AUC for Testing Set: 0.7143
