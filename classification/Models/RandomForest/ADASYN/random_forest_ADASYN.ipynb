# %%
# !pip install optuna

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import ADASYN
import optuna
import joblib

# Read data
data = pd.read_excel('TrainClass.xlsx')
real_data = pd.read_excel('TestClass.xlsx')

# Split data
Y, X = data['FRACASO'], data.drop(['FRACASO', 'CODIGO_EMPRESA'], axis=1)

# Apply ADASYN
adasyn = ADASYN(random_state=0)
X_resampled, Y_resampled = adasyn.fit_resample(X, Y)

X_train, X_test, Y_train, Y_test = train_test_split(X_resampled, Y_resampled, test_size=0.2, random_state=0)
X = real_data.drop(['CODIGO_EMPRESA'], axis=1)

# Define the objective function for cross-validated AUC
def objective(trial):
    # Define hyperparameters to be optimized
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 1, 10)

    # Create the classifier with suggested hyperparameters
    clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=0)

    # Define cross-validation strategy (StratifiedKFold for classification)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    # Perform cross-validation and get mean AUC
    auc_scores = cross_val_score(clf, X_train, Y_train, cv=cv, scoring='roc_auc')
    mean_auc = auc_scores.mean()

    return mean_auc

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Get the best hyperparameters
best_params = study.best_params
print(f'Best Hyperparameters: {best_params}')

# Train the final model with the best hyperparameters
best_clf = RandomForestClassifier(**best_params, random_state=0)
best_clf.fit(X_train, Y_train)

# Predictions on training set
y_pred_train = best_clf.predict(X_train)

# Calculate AUC for training set
auc_train = roc_auc_score(Y_train, y_pred_train)
print(f'AUC for Training Set: {auc_train:.4f}')

# Predictions on testing set
y_pred_test = best_clf.predict(X_test)

# Calculate AUC for testing set
auc_test = roc_auc_score(Y_test, y_pred_test)
print(f'AUC for Testing Set: {auc_test:.4f}')

# Save the trained model to a file
joblib.dump(best_clf, 'random_forest_model.joblib')

# Load model and generate probability CSV
loaded_model = joblib.load('random_forest_model.joblib')
prob = loaded_model.predict_proba(X)[:, 1]
prob_df = pd.DataFrame(prob, columns=['Probability'])
prob_df.index = prob_df.index + 1
prob_df.index.name = 'Id'
prob_df.to_csv('intento.csv', index=True)
# Out:
# [I 2023-12-05 15:48:17,804] A new study created in memory with name: no-name-220a3562-24c7-4da5-b78e-62d6433a6f06
# [I 2023-12-05 15:48:24,822] Trial 0 finished with value: 0.958504212608932 and parameters: {'n_estimators': 162, 'max_depth': 6}. Best is trial 0 with value: 0.958504212608932.
# [I 2023-12-05 15:48:28,974] Trial 1 finished with value: 0.8387431047922058 and parameters: {'n_estimators': 182, 'max_depth': 1}. Best is trial 0 with value: 0.958504212608932.
# [I 2023-12-05 15:48:38,257] Trial 2 finished with value: 0.9885357706509537 and parameters: {'n_estimators': 172, 'max_depth': 9}. Best is trial 2 with value: 0.9885357706509537.
# [I 2023-12-05 15:48:45,903] Trial 3 finished with value: 0.9737456661251809 and parameters: {'n_estimators': 131, 'max_depth': 7}. Best is trial 2 with value: 0.9885357706509537.
# [I 2023-12-05 15:48:48,898] Trial 4 finished with value: 0.9723191601213894 and parameters: {'n_estimators': 64, 'max_depth': 7}. Best is trial 2 with value: 0.9885357706509537.
# [I 2023-12-05 15:48:56,991] Trial 5 finished with value: 0.9585404602244492 and parameters: {'n_estimators': 180, 'max_depth': 6}. Best is trial 2 with value: 0.9885357706509537.
# [I 2023-12-05 15:49:02,599] Trial 6 finished with value: 0.8854475580005492 and parameters: {'n_estimators': 151, 'max_depth': 3}. Best is trial 2 with value: 0.9885357706509537.
# [I 2023-12-05 15:49:07,881] Trial 7 finished with value: 0.9873554400132051 and parameters: {'n_estimators': 102, 'max_depth': 9}. Best is trial 2 with value: 0.9885357706509537.
# [I 2023-12-05 15:49:13,255] Trial 8 finished with value: 0.8853618236749785 and parameters: {'n_estimators': 190, 'max_depth': 3}. Best is trial 2 with value: 0.9885357706509537.
# [I 2023-12-05 15:49:17,626] Trial 9 finished with value: 0.8584395008908775 and parameters: {'n_estimators': 144, 'max_depth': 2}. Best is trial 2 with value: 0.9885357706509537.
# [I 2023-12-05 15:49:24,511] Trial 10 finished with value: 0.9915178531830964 and parameters: {'n_estimators': 103, 'max_depth': 10}. Best is trial 10 with value: 0.9915178531830964.
# [I 2023-12-05 15:49:37,118] Trial 11 finished with value: 0.9915255263156221 and parameters: {'n_estimators': 102, 'max_depth': 10}. Best is trial 11 with value: 0.9915255263156221.
# [I 2023-12-05 15:49:42,461] Trial 12 finished with value: 0.9915723290896719 and parameters: {'n_estimators': 99, 'max_depth': 10}. Best is trial 12 with value: 0.9915723290896719.
# [I 2023-12-05 15:49:47,628] Trial 13 finished with value: 0.9911656285934743 and parameters: {'n_estimators': 78, 'max_depth': 10}. Best is trial 12 with value: 0.9915723290896719.
# [I 2023-12-05 15:49:53,865] Trial 14 finished with value: 0.9831509642597179 and parameters: {'n_estimators': 104, 'max_depth': 8}. Best is trial 12 with value: 0.9915723290896719.
# [I 2023-12-05 15
. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:52:48,354] Trial 37 finished with value: 0.9882985717735228 and parameters: {'n_estimators': 164, 'max_depth': 9}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:52:56,114] Trial 38 finished with value: 0.9586913822381089 and parameters: {'n_estimators': 187, 'max_depth': 6}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:52:59,462] Trial 39 finished with value: 0.8392986697050328 and parameters: {'n_estimators': 159, 'max_depth': 1}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:53:08,323] Trial 40 finished with value: 0.9737391734771969 and parameters: {'n_estimators': 173, 'max_depth': 7}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:53:17,616] Trial 41 finished with value: 0.9920390133666348 and parameters: {'n_estimators': 145, 'max_depth': 10}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:53:26,957] Trial 42 finished with value: 0.992166808780269 and parameters: {'n_estimators': 163, 'max_depth': 10}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:53:38,359] Trial 43 finished with value: 0.9884784334178928 and parameters: {'n_estimators': 183, 'max_depth': 9}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:53:48,399] Trial 44 finished with value: 0.9921824789299535 and parameters: {'n_estimators': 165, 'max_depth': 10}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:53:58,129] Trial 45 finished with value: 0.9922554434521128 and parameters: {'n_estimators': 166, 'max_depth': 10}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:54:09,528] Trial 46 finished with value: 0.9831277900745852 and parameters: {'n_estimators': 196, 'max_depth': 8}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:54:19,454] Trial 47 finished with value: 0.9885071552107807 and parameters: {'n_estimators': 177, 'max_depth': 9}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:54:29,601] Trial 48 finished with value: 0.9922398176925356 and parameters: {'n_estimators': 169, 'max_depth': 10}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:54:40,144] Trial 49 finished with value: 0.9884369037874977 and parameters: {'n_estimators': 170, 'max_depth': 9}. Best is trial 31 with value: 0.992286595484404.
# [I 2023-12-05 15:54:51,259] Trial 50 finished with value: 0.9923751401524162 and parameters: {'n_estimators': 192, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:55:02,617] Trial 51 finished with value: 0.9923412750212487 and parameters: {'n_estimators': 191, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:55:14,662] Trial 52 finished with value: 0.9923751401524162 and parameters: {'n_estimators': 192, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:55:26,645] Trial 53 finished with value: 0.9923204624509971 and parameters: {'n_estimators': 190, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:55:36,618] Trial 54 finished with value: 0.9883924925049786 and parameters: {'n_estimators': 191, 'max_depth': 9}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:55:48,214] Trial 55 finished with value: 0.9921770412777855 and parameters: {'n_estimators': 183, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:55:59,980] Trial 56 finished with value: 0.9884080455273205 and parameters: {'n_estimators': 193, 'max_depth': 9}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:56:10,171] Trial 57 finished with value: 0.9830391415010924 and parameters: {'n_estimators': 200, 'max_depth': 8}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:56:21,576] Trial 58 finished with value: 0.9922265614333714 and parameters: {'n_estimators': 186, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:56:27,024] Trial 59 finished with value: 0.8855049202837698 and parameters: {'n_estimators': 180, 'max_depth': 3}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:56:38,428] Trial 60 finished with value: 0.9923204624509971 and parameters: {'n_estimators': 190, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:56:50,382] Trial 61 finished with value: 0.9923204624509971 and parameters: {'n_estimators': 190, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:57:01,745] Trial 62 finished with value: 0.9884080455273205 and parameters: {'n_estimators': 193, 'max_depth': 9}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:57:12,217] Trial 63 finished with value: 0.9922292326573535 and parameters: {'n_estimators': 188, 'max_depth': 10}. Best is trial 50 with value: 0.9923751401524162.
# [I 2023-12-05 15:57:24,722] Trial 64 finished with value: 0.9923907283197589 and parameters: {'n_estimators': 200, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:57:36,807] Trial 65 finished with value: 0.988428924036935 and parameters: {'n_estimators': 200, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:57:48,004] Trial 66 finished with value: 0.9923751401524162 and parameters: {'n_estimators': 192, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:57:58,292] Trial 67 finished with value: 0.9884133278481029 and parameters: {'n_estimators': 180, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:58:10,469] Trial 68 finished with value: 0.9923621714092677 and parameters: {'n_estimators': 194, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:58:16,665] Trial 69 finished with value: 0.9106423451216653 and parameters: {'n_estimators': 195, 'max_depth': 4}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:58:28,527] Trial 70 finished with value: 0.9922291959828314 and parameters: {'n_estimators': 185, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:58:40,710] Trial 71 finished with value: 0.9923621714092677 and parameters: {'n_estimators': 194, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:58:56,710] Trial 72 finished with value: 0.9923517121347262 and parameters: {'n_estimators': 198, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:59:07,499] Trial 73 finished with value: 0.9884445183903414 and parameters: {'n_estimators': 196, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:59:19,475] Trial 74 finished with value: 0.9923907283197589 and parameters: {'n_estimators': 200, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:59:32,083] Trial 75 finished with value: 0.9923907283197589 and parameters: {'n_estimators': 200, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:59:43,321] Trial 76 finished with value: 0.9923126691320864 and parameters: {'n_estimators': 176, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 15:59:53,883] Trial 77 finished with value: 0.9884002337181969 and parameters: {'n_estimators': 199, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:00:06,255] Trial 78 finished with value: 0.9923465921811273 and parameters: {'n_estimators': 195, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:00:17,633] Trial 79 finished with value: 0.9884628763508168 and parameters: {'n_estimators': 181, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:00:21,382] Trial 80 finished with value: 0.9911398754654781 and parameters: {'n_estimators': 68, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:00:33,329] Trial 81 finished with value: 0.9922265614333714 and parameters: {'n_estimators': 186, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:00:45,235] Trial 82 finished with value: 0.9923907283197589 and parameters: {'n_estimators': 200, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:00:56,653] Trial 83 finished with value: 0.9923621714092677 and parameters: {'n_estimators': 194, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:01:09,289] Trial 84 finished with value: 0.9923907283197589 and parameters: {'n_estimators': 200, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:01:21,508] Trial 85 finished with value: 0.988428924036935 and parameters: {'n_estimators': 200, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:01:32,320] Trial 86 finished with value: 0.9922265614333714 and parameters: {'n_estimators': 186, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:01:43,696] Trial 87 finished with value: 0.9884184838644149 and parameters: {'n_estimators': 197, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:01:54,763] Trial 88 finished with value: 0.9831434753495358 and parameters: {'n_estimators': 189, 'max_depth': 8}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:02:05,447] Trial 89 finished with value: 0.9922944279250707 and parameters: {'n_estimators': 177, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:02:16,252] Trial 90 finished with value: 0.9922369886899336 and parameters: {'n_estimators': 184, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:02:28,551] Trial 91 finished with value: 0.9923543660921123 and parameters: {'n_estimators': 193, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:02:41,065] Trial 92 finished with value: 0.9923465345691582 and parameters: {'n_estimators': 196, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:02:52,781] Trial 93 finished with value: 0.9923907283197589 and parameters: {'n_estimators': 200, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:03:04,236] Trial 94 finished with value: 0.9884002337181969 and parameters: {'n_estimators': 199, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:03:16,855] Trial 95 finished with value: 0.9923907283197589 and parameters: {'n_estimators': 200, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:03:28,847] Trial 96 finished with value: 0.9922292326573535 and parameters: {'n_estimators': 188, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:03:39,202] Trial 97 finished with value: 0.9884080825077467 and parameters: {'n_estimators': 192, 'max_depth': 9}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:03:49,015] Trial 98 finished with value: 0.9588189859517398 and parameters: {'n_estimators': 200, 'max_depth': 6}. Best is trial 64 with value: 0.9923907283197589.
# [I 2023-12-05 16:04:01,530] Trial 99 finished with value: 0.9923309100331981 and parameters: {'n_estimators': 197, 'max_depth': 10}. Best is trial 64 with value: 0.9923907283197589.
# Best Hyperparameters: {'n_estimators': 200, 'max_depth': 10}
# AUC for Training Set: 0.9953
# AUC for Testing Set: 0.9576
